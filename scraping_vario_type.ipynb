# %%
# !pip install bing-image-downloader

# %%
# !mkdir dataset_gambar

# %%
from bing_image_downloader import downloader

# %%
downloader.download('motor vario techo 110 (2009-2013)', limit = 300, output_dir='dataset_gambar', adult_filter_off=True)

# %%
downloader.download('motor vario techno 125 FI (2012 - 2015)', limit = 300, output_dir='dataset_gambar', adult_filter_off=True)
# Out:
# [%] Downloading Images to /content/dataset_gambar/motor vario techno 125 FI (2012 - 2015)
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://3.bp.blogspot.com/-z3dbuFIOWns/URl6YGVL3gI/AAAAAAAAA6I/vr_YJTpB4qo/s1600/Honda+Vario+Techno+125+PGM-FI+Swift+White+Silver.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from http://2.bp.blogspot.com/-WfsNOkCK-QE/UfPkANwT9tI/AAAAAAAABGQ/lY98pBNMT8M/s1600/Vario+125+Idling+Stop+Bionic+Red.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://img4.icarcdn.com/7203172/gallery_used-mcycle-mobil123-honda-vario-indonesia_7203172_cd4860181448833080985_v1sm.jpg?smia=xTM
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://www.jualmotorbekas.com/uploads/2015/04/327920.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://www.hondacengkareng.com/wp-content/uploads/2018/10/honda-vario-techno-125-cbs-iss-white-silver.jpg
# [%] File Downloaded !
#
# ...

# %%
downloader.download('motor vario 160 (2022-now)', limit = 300, output_dir='dataset_gambar', adult_filter_off=True)
# Out:
# [%] Downloading Images to /content/dataset_gambar/motor vario 160 (2022-now)
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://img.varioholic.com/730x0_ardiantoyugo.com/wp-content/uploads/2022/02/honda-vario-160-2022-abs.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://ardiantoyugo.com/wp-content/uploads/2022/02/honda-vario-160-2022-abs-2.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://imgcdn.oto.com/large/gallery/exterior/73/2569/honda-vario-160-slant-front-view-full-image-809796.jpg
# [Error]Invalid image, not saving https://imgcdn.oto.com/large/gallery/exterior/73/2569/honda-vario-160-slant-front-view-full-image-809796.jpg
#
# [!] Issue getting: https://imgcdn.oto.com/large/gallery/exterior/73/2569/honda-vario-160-slant-front-view-full-image-809796.jpg
# ...

# %%
# !zip -r '/content/dataset_gambar.zip' '/content/dataset_gambar'
# Out:
#   adding: content/dataset_gambar/ (stored 0%)
#   adding: content/dataset_gambar/motor vario 110 (2009-2013)/ (stored 0%)
#   adding: content/dataset_gambar/motor vario 110 (2009-2013)/Image_238.jpg (deflated 3%)
#   adding: content/dataset_gambar/motor vario 110 (2009-2013)/Image_209.jpg (deflated 5%)
#   adding: content/dataset_gambar/motor vario 110 (2009-2013)/Image_236.jpg (deflated 6%)
#   adding: content/dataset_gambar/motor vario 110 (2009-2013)/Image_109.jpeg (deflated 0%)
#   adding: content/dataset_gambar/motor vario 110 (2009-2013)/Image_263.jpg (deflated 3%)
#   adding: content/dataset_gambar/motor vario 110 (2009-2013)/Image_201.jpg (deflated 1%)
#   adding: content/dataset_gambar/motor vario 110 (2009-2013)/Image_140.jpg (deflated 0%)
#   adding: content/dataset_gambar/motor vario 110 (2009-2013)/Image_143.jpg (deflated 0%)
#   adding: content/dataset_gambar/motor vario 110 (2009-2013)/Image_111.jpg (deflated 0%)
# ...
